# %%
from imblearn.over_sampling import RandomOverSampler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split

# Set random seed for reproducibility
np.random.seed(42)

# Generate imbalanced dataset
n_samples_1 = 25  # Number of samples in class 1
n_samples_2 = 375  # Number of samples in class 2
centers = [(0, 0), (2, 2)]  # Centers of each cluster
cluster_std = [1.5, 1.5]  # Standard deviation of each cluster

X, y = make_blobs(n_samples=[n_samples_1, n_samples_2],
                  centers=centers,
                  cluster_std=cluster_std,
                  random_state=0)
plt.figure(figsize=(8, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='red', label='Class 1')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='blue', label='Class 2')
plt.title('2D Imbalanced Dataset with Two Classes')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(class_weight={0:5,1:1})
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight={0: 5, 1: 1})

# %%
lr2 =LogisticRegression()
lr2.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
import matplotlib.pyplot as plt

# %%
response = lr.predict(X_test)
fig,axs=plt.subplots(1,2,figsize=(12,5))
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train,y_train,clf=lr,ax=axs[0])
plot_decision_regions(X_train,y_train,clf=lr2,ax=axs[1])
axs[0].set_title("With adding weight")
axs[1].set_title("Without adding weight")
# Out:
# Text(0.5, 1.0, 'Without adding weight')

# %%
! pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (1.18.0)
# Requirement already satisfied: numpy>=2.3.5 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (3.11.1)
# Requirement already satisfied: joblib>=1.5.2 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (26.3)
# Requirement already satisfied: pillow>=9 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from pandas>=2.3.3->mlxtend) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from pandas>=2.3.3->mlxtend) (2026.3)
# Requirement already satisfied: six>=1.5 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /run/media/darshchouhan/New Volume/ML-Algorithm/venv/lib64/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
