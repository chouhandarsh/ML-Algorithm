# %% [markdown]
# ### Random Forest is --> Group of trees it is a bagging technique which means bootstrapped aggrigation
# - If in the Bagging technique if we will use all the descision trees then it is Random Forest
