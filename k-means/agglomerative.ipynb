# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In agglomarative function what we do is that we  first we

# %% [markdown]
# ## Types of agglomarative Clustering
# - Min Single-Link: In this the smaller distance are taken to make the cluster
# - Max(Complete Link): In this we are taking the larger distance for making the clusters
# - Average in this we take the avertage of all the points in the dataset for the calculation of distance
# ![image.png](attachment:image.png)
# - Ward
# #### All these types are based on the calculation of distance form each point

# %% [markdown]
# # Finding the number of groups in the data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
