# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/run/media/darshchouhan/New Volume/100 days/DATA SETS/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X =  df.drop("Outcome",axis=1)

# %%
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /home/darshchouhan/.local/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_prob = model.predict_proba(X_test)

# %%
y_prob[:,1]
# Out:
# array([0.15477953, 0.28336505, 0.97992512, 0.16361839, 0.67392914,
#        0.07866609, 0.32694582, 0.07817167, 0.06941261, 0.10103477,
#        0.1790334 , 0.12621964, 0.52995248, 0.29375886, 0.16713484,
#        0.26751314, 0.17105902, 0.55564051, 0.22286366, 0.2824274 ,
#        0.52286884, 0.263211  , 0.39616972, 0.50852579, 0.40718744,
#        0.49580358, 0.76012718, 0.59730644, 0.02970126, 0.33275543,
#        0.35802682, 0.49057534, 0.99025274, 0.33879988, 0.44978386,
#        0.6210791 , 0.2557885 , 0.63241566, 0.127915  , 0.53452644,
#        0.07453377, 0.06448531, 0.75641283, 0.31703534, 0.16687571,
#        0.17547368, 0.16251223, 0.23187029, 0.60889737, 0.07190792,
#        0.12128254, 0.19447621, 0.04538228, 0.28346346, 0.38299483,
#        0.97146496, 0.18421358, 0.67720424, 0.1998366 , 0.69613786,
#        0.75968629, 0.44736047, 0.06195919, 0.73386848, 0.34210665,
#        0.35638866, 0.03217238, 0.19602849, 0.0662884 , 0.65258078,
# ...

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import roc_curve
fpr,tpr,thresholds = roc_curve(y_test,y_pred)

# %%
import plotly.graph_objects as go

# %%
y_test.shape
# Out:
# (192,)

# %%
y_prob=y_prob[:,1]

# %%
y_prob.shape
# Out:
# (192,)

# %%
import plotly.graph_objects as go
import numpy as np
from sklearn.metrics import roc_auc_score

# Assuming fpr, tpr, thresholds are already calculated as before
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Calculate the AUC (Area Under the Curve)
roc_auc = roc_auc_score(y_test, y_prob)

# Generate a trace for ROC curve
trace0 = go.Scatter(
    x=fpr,
    y=tpr,
    mode='lines',
    name=f'ROC curve (Area = {roc_auc:.2f})'
)

# Only label every nth point to avoid cluttering
n = 10
indices = np.arange(len(thresholds)) % n == 0  # Choose indices where index mod n is 0

trace1 = go.Scatter(
    x=fpr[indices],
    y=tpr[indices],
    mode='markers+text',
    name='Threshold points',
    text=[f"Thr={thr:.2f}" for thr in thresholds[indices]],
    textposition='top center'
)

# Diagonal line
trace2 = go.Scatter(
    x=[0, 1],
    y=[0, 1],
    mode='lines',
    name='Random (Area = 0.5)',
    line=dict(dash='dash')
)

data = [trace0, trace1, trace2]

# Define layout with square aspect ratio
layout = go.Layout(
    title='Receiver Operating Characteristic',
    xaxis=dict(title='False Positive Rate'),
    yaxis=dict(title='True Positive Rate'),
    autosize=False,
    width=800,
    height=800,
    showlegend=True
)

# Define figure and add data
fig = go.Figure(data=data, layout=layout)

# Show figure
fig.show()

# %% [markdown]
# ### What basically is done that when we give the real results and  the probabilities then the roc score function checks all the probabilites and checks the AUC and the ROC of it after which we check the graph

# %% [markdown]
# - TPR means true positive rate and  FPR means false Positive rate

# %% [markdown]
# $$
# \boxed{T.P.R = \frac{TP}{TP+FN}}
# $$

# %% [markdown]
# - TP means that it is actually true and  the model predicts it to be true
# - FN means that it  is actually true and the model predicts it to be false
# - Better model means the maximum TPR

# %% [markdown]
# $$
# \boxed{F.P.R = \frac{FP}{FP+FN}}
# $$

# %% [markdown]
# - FPR should be minimum
# - FP means that the it was originally false and the model predict it  to  be positive
# - FN means that it was origanlly false and the model predictes it to be  false

# %% [markdown]
# - For that we will try to get the maximum distance form the line

# %% [markdown]
# # AUC-ROC
#
# The **AUC-ROC** measures the **entire two-dimensional area underneath the entire ROC curve** from **(0,0) to (1,1)**. AUC provides an aggregate measure of performance across all possible classification thresholds.
#
# - An **AUC of 1** indicates that the model has **perfect discrimination**: it correctly classifies all positive and negative instances.
# - An **AUC of 0.5** suggests the model has **no discrimination ability**: it is as good as random guessing.
# - An **AUC of 0** indicates that the model is **perfectly wrong**: it classifies all positive instances as negative and all negative instances as positive.
#
# In practice, **AUC values usually fall between 0.5 (random) and 1 (perfect)**, with higher values indicating better classification performance.

# %% [markdown]
# ## It is  also use  to create a distinction between the two different models

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split   
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %%
X.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %% [markdown]
# So there is the problem  in this dataset that it is not uniform so we will have to scale it

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled =  pd.DataFrame(X_train_scaled,columns=X_test.columns)

# %%
X_train_scaled.describe()
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  5.760000e+02  5.760000e+02   5.760000e+02   5.760000e+02  5.760000e+02
# mean   1.696174e-17  1.333810e-16  -6.167906e-18  -7.709882e-17 -4.934325e-17
# std    1.000869e+00  1.000869e+00   1.000869e+00   1.000869e+00  1.000869e+00
# min   -1.167304e+00 -3.720261e+00  -3.537279e+00  -1.295125e+00 -6.780013e-01
# 25%   -8.659289e-01 -6.529983e-01  -3.443938e-01  -1.295125e+00 -6.780013e-01
# 50%   -2.631796e-01 -1.262965e-01   6.759131e-02   1.727350e-01 -5.349505e-01
# 75%    6.409444e-01  5.863000e-01   5.053255e-01   7.471149e-01  3.738430e-01
# max    3.956066e+00  2.445247e+00   2.745495e+00   2.725535e+00  6.440881e+00
#
#                 BMI  DiabetesPedigreeFunction           Age
# count  5.760000e+02              5.760000e+02  5.760000e+02
# mean   1.912051e-16             -3.083953e-16 -6.167906e-18
# std    1.000869e+00              1.000869e+00  1.000869e+00
# ...

# %%
from sklearn.linear_model import LogisticRegression
regression = LogisticRegression()

# %%
regression.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.svm import SVC
svc =  SVC(probability=True)
svc.fit(X_train_scaled,y_train)
# Out:
# SVC(probability=True)

# %%
X_test_transformed = scaler.transform(X_test)

# %%
from sklearn.metrics import r2_score,accuracy_score
y_reg = regression.predict(X_test_transformed)
print(accuracy_score(y_test,y_reg))
y_svc  =svc.predict(X_test_transformed)
print(accuracy_score(y_test,y_svc))
# Out:
# 0.7916666666666666
# 0.75
# /home/darshchouhan/.local/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /home/darshchouhan/.local/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
y_reg_p = regression.predict_proba(X_test_transformed)
y_svc_p  =svc.predict_proba(X_test_transformed)
# Out:
# /home/darshchouhan/.local/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /home/darshchouhan/.local/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
tpr_r,fpr_r,thresholds_r = roc_curve(y_test,y_reg_p[:,0])
tpr_s,fpr_s,thresholds_s = roc_curve(y_test,y_svc_p[:,0])

# %%
svm_auc = roc_auc_score(y_test, y_reg_p[:,1])
lr_auc = roc_auc_score(y_test, y_svc_p[:,1])

# %%
# Generate a trace for the Logistic Regression ROC curve
trace0 = go.Scatter(
    x=fpr_r,
    y=tpr_r,
    mode='lines',
    name=f'Logistic Regression (Area = {lr_auc:.2f})'
)

# Generate a trace for the SVM ROC curve
trace1 = go.Scatter(
    x=fpr_s,
    y=tpr_s,
    mode='lines',
    name=f'SVM (Area = {svm_auc:.2f})'
)

# Diagonal line
trace2 = go.Scatter(
    x=[0, 1],
    y=[0, 1],
    mode='lines',
    name='Random (Area = 0.5)',
    line=dict(dash='dash')
)

data = [trace0, trace1, trace2]

# Define layout with square aspect ratio
layout = go.Layout(
    title='Receiver Operating Characteristic',
    xaxis=dict(title='False Positive Rate'),
    yaxis=dict(title='True Positive Rate'),
    autosize=False,
    width=800,
    height=800,
    showlegend=True
)

# Define figure and add data
fig = go.Figure(data=data, layout=layout)

# Show figure
fig.show()
