# %% [markdown]
# ## Why ROC curve

# %% [markdown]
# ## TRP True Positive rate

# %% [markdown]
# ### tpr = $\frac{TP}{TP+FN}$

# %% [markdown]
# # FPR

# %% [markdown]
# - # FPR = $\frac{FP}{FP+TN}$

# %% [markdown]
# - FPR tells the cost of the model it should be as low as possible

# %% [markdown]
# ## ROC curve
# - It is the graph between the FPR and  TPR
# - we wll check for and FPR and TPR for some thereshold and plot the curve from it

# %% [markdown]
# $$
# \boxed{
# L
# =
# -\frac{1}{m}
# \left[
# Y^{T}\log((\hat{y_i}))
# +
# (1-Y_i)^{T}\log(1-\hat{y_i})
# \right]
# }
# $$
